# %% [raw]
# ---
# description: A minimal working example of supporting `_brand.yml` in ndbev.
# output-file: index.html
# title: nbdev_brand
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some useful pointers to get you started.

# %% [markdown]
# ### Install nbdev_brand in Development mode

# %% [markdown]
# ```sh
# # make sure nbdev_brand package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbdev_brand
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/marcusinthesky/nbdev_brand.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c marcusinthesky nbdev_brand
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbdev_brand
# ```
#
#
# [repo]: https://github.com/marcusinthesky/nbdev_brand
# [docs]: https://marcusinthesky.github.io/nbdev_brand/
# [pypi]: https://pypi.org/project/nbdev_brand/
# [conda]: https://anaconda.org/marcusinthesky/nbdev_brand

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/marcusinthesky/nbdev_brand
# [docs]: https://marcusinthesky.github.io/nbdev_brand/
# [pypi]: https://pypi.org/project/nbdev_brand/
# [conda]: https://anaconda.org/marcusinthesky/nbdev_brand

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
